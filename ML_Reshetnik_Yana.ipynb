# %% [markdown]
# <a href="https://colab.research.google.com/github/yan4ikk/Machine-learning/blob/main/ML_Reshetnik_Yana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # О датасете

# %% [markdown]
# Околоземные объекты — это астероиды и кометы, орбиты которых позволяют им находиться в пределах 120 миллионов миль (195 миллионов километров) от Солнца, что означает, что они могут вращаться вокруг орбиты Земли. Большинство околоземных объектов представляют собой астероиды, размер которых варьируется от примерно 10 футов (несколько метров) до почти 25 миль (40 километров) в поперечнике.
#
# Орбита каждого объекта вычисляется путем нахождения эллиптической траектории в пространстве, которая лучше всего соответствует всем доступным наблюдениям, которые часто охватывают множество орбит за многие годы или десятилетия. По мере того, как проводится больше наблюдений, точность орбиты объекта резко улучшается, и становится возможным предсказать, где объект будет находиться через годы или даже десятилетия в будущем – и сможет ли он приблизиться к Земле.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

df = pd.read_csv("/content/NASA Near-Earth Objects.csv")
df = df.drop('Unnamed: 0',axis='columns')
df
# Out:
#              id  neo_reference_id                        name name_limited  \
# 0       2001981           2001981        1981 Midas (1973 EA)        Midas
# 1       2002059           2002059  2059 Baboquivari (1963 UA)  Baboquivari
# 2       2002061           2002061         2061 Anza (1960 UA)         Anza
# 3       2002062           2002062         2062 Aten (1976 AA)         Aten
# 4       2002063           2002063      2063 Bacchus (1977 HB)      Bacchus
# ...         ...               ...                         ...          ...
# 23995  54073361          54073361                   (2020 UQ)          NaN
# 23996  54073362          54073362                   (2020 UR)          NaN
# 23997  54073363          54073363                   (2020 US)          NaN
# 23998  54073365          54073365                   (2020 UT)          NaN
# 23999  54073367          54073367                   (2020 UU)          NaN
#
#       designation  absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0            1981                 15.22                               True
# 1            2059                 15.97                              False
# 2            2061                 16.36                              False
# 3            2062                 17.10                              False
# 4            2063                 17.28                              False
# ...           ...                   ...                                ...
# 23995     2020 UQ                 26.90                              False
# 23996     2020 UR                 27.90                              False
# 23997     2020 US                 27.20                              False
# 23998     2020 UT                 27.33                              False
# 23999     2020 UU                 28.81                              False
#
#        is_sentry_object  kilometers_estimated_diameter_min  \
# 0                 False                           2.401900
# 1                 False                           1.700415
# 2                 False                           1.420872
# 3                 False                           1.010543
# 4                 False                           0.930154
# ...                 ...                                ...
# 23995             False                           0.011080
# 23996             False                           0.006991
# 23997             False                           0.009651
# 23998             False                           0.009090
# 23999             False                           0.004598
#
#        kilometers_estimated_diameter_max orbit_id orbit_class_type  \
# 0                               5.370812      229              APO
# 1                               3.802244      268              AMO
# 2                               3.177167      180              AMO
# 3                               2.259644      149              ATE
# 4                               2.079888      143              APO
# ...                                  ...      ...              ...
# 23995                           0.024777        3              APO
# 23996                           0.015633        4              APO
# 23997                           0.021579        5              APO
# 23998                           0.020325        2              AMO
# 23999                           0.010281        2              APO
#
#        perihelion_distance  aphelion_distance first_observation_date  \
# 0                 0.621512           2.931360             1973-03-06
# 1                 1.238537           4.047945             1963-10-16
# 2                 1.050403           3.478155             1960-10-22
# 3                 0.790185           1.143633             1955-12-17
# 4                 0.701397           1.454804             1977-04-24
# ...                    ...                ...                    ...
# 23995             0.608650           1.901363             2020-10-16
# 23996             0.732739           1.887929             2020-10-16
# 23997             0.788983           2.851299             2020-10-16
# 23998             1.045124           4.170737             2020-10-15
# 23999             0.928007           2.201763             2020-10-17
#
#       last_observation_date                            orbit_class_description
# 0                2021-10-20  Near-Earth asteroid orbits which cross the Ear...
# 1                2021-04-15  Near-Earth asteroid orbits similar to that of ...
# 2                2021-06-12  Near-Earth asteroid orbits similar to that of ...
# 3                2019-11-10  Near-Earth asteroid orbits similar to that of ...
# 4                2021-12-02  Near-Earth asteroid orbits which cross the Ear...
# ...                     ...                                                ...
# 23995            2020-10-19  Near-Earth asteroid orbits which cross the Ear...
# 23996            2020-10-19  Near-Earth asteroid orbits which cross the Ear...
# 23997            2020-10-21  Near-Earth asteroid orbits which cross the Ear...
# 23998            2020-10-18  Near-Earth asteroid orbits similar to that of ...
# 23999            2020-10-18  Near-Earth asteroid orbits which cross the Ear...
#
# [24000 rows x 17 columns]

# %%
df.shape    # Размер датасета (Количество строк: 24000; количество признаков: 17)
# Out:
# (24000, 17)

# %%
df.head()
# Out:
#         id  neo_reference_id                        name name_limited  \
# 0  2001981           2001981        1981 Midas (1973 EA)        Midas
# 1  2002059           2002059  2059 Baboquivari (1963 UA)  Baboquivari
# 2  2002061           2002061         2061 Anza (1960 UA)         Anza
# 3  2002062           2002062         2062 Aten (1976 AA)         Aten
# 4  2002063           2002063      2063 Bacchus (1977 HB)      Bacchus
#
#   designation  absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0        1981                 15.22                               True
# 1        2059                 15.97                              False
# 2        2061                 16.36                              False
# 3        2062                 17.10                              False
# 4        2063                 17.28                              False
#
#    is_sentry_object  kilometers_estimated_diameter_min  \
# 0             False                           2.401900
# 1             False                           1.700415
# 2             False                           1.420872
# 3             False                           1.010543
# 4             False                           0.930154
#
#    kilometers_estimated_diameter_max orbit_id orbit_class_type  \
# 0                           5.370812      229              APO
# 1                           3.802244      268              AMO
# 2                           3.177167      180              AMO
# 3                           2.259644      149              ATE
# 4                           2.079888      143              APO
#
#    perihelion_distance  aphelion_distance first_observation_date  \
# 0             0.621512           2.931360             1973-03-06
# 1             1.238537           4.047945             1963-10-16
# 2             1.050403           3.478155             1960-10-22
# 3             0.790185           1.143633             1955-12-17
# 4             0.701397           1.454804             1977-04-24
#
#   last_observation_date                            orbit_class_description
# 0            2021-10-20  Near-Earth asteroid orbits which cross the Ear...
# 1            2021-04-15  Near-Earth asteroid orbits similar to that of ...
# 2            2021-06-12  Near-Earth asteroid orbits similar to that of ...
# 3            2019-11-10  Near-Earth asteroid orbits similar to that of ...
# 4            2021-12-02  Near-Earth asteroid orbits which cross the Ear...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 24000 non-null  int64
#  1   neo_reference_id                   24000 non-null  int64
#  2   name                               24000 non-null  object
#  3   name_limited                       144 non-null    object
#  4   designation                        24000 non-null  object
#  5   absolute_magnitude_h               23992 non-null  float64
#  6   is_potentially_hazardous_asteroid  24000 non-null  bool
#  7   is_sentry_object                   24000 non-null  bool
#  8   kilometers_estimated_diameter_min  23992 non-null  float64
#  9   kilometers_estimated_diameter_max  23992 non-null  float64
#  10  orbit_id                           24000 non-null  object
#  11  orbit_class_type                   24000 non-null  object
#  12  perihelion_distance                24000 non-null  float64
#  13  aphelion_distance                  24000 non-null  float64
#  14  first_observation_date             24000 non-null  object
#  15  last_observation_date              24000 non-null  object
#  16  orbit_class_description            24000 non-null  object
# dtypes: bool(2), float64(5), int64(2), object(8)
# memory usage: 2.8+ MB

# %% [markdown]
# Признаки
#
#
# *   'id' - уникальный id, присвоенный NASA
# *   'neo_reference_id' (NEO ID) - повторяет id
# *   'name' - официальное имя околоземного объекта, присвоенное NASA
# *   'name_limited'-  наименование без использования научных обозначений
# *  'designation' - число, используемое в официальном обозначении NASA
# *   'absolute_magnitude_h' - абсолютная звездная величина (М) - является мерой светимости небесного объекта в обратной логарифмической шкале астрономической величины. Определяется как равная видимой величине, которую объект имел бы,
# если бы его рассматривали с расстояния ровно 10 парсек (32,6 световых лет),
# без поглощения его света из-за затемнения межзвездным веществом и космической пылью.
# *   'is_potentially_hazardous_asteroid' - логическое значение, которое сообщает,
# представляет ли объект потенциальную угрозу для Земли или нет
# *   'is_sentry_object' - логическое значение, которое сообщает,
# присутствует ли объект в системе слежения за столкновениями с Землей
# *   'kilometers_estimated_diameter_min' - минимальный расчетный диаметр в километрах
# *  'kilometers_estimated_diameter_max' - максимальный расчетный диаметр в километрах
# *   'orbit_id' - уникальный id орбиты объекта
# *   'orbit_class_type' - классификация орбит
# *   'perihelion_distance' - перигелийное расстояние (ближайшая к Земле точка на пути вращающегося небесного тела)
# *   'aphelion_distance' - афелийное расстояние (точка на орбите планеты, астероида или др. объекта, в которой он находится дальше всего от Земли)
# *   'first_observation_date' - дата, когда объект был впервые замечен
# *   'last_observation_date' - дата, когда объект наблюдался последний раз
# *  'orbit_class_description' - описание орбиты

# %%
df.describe()
# Out:
#                  id  neo_reference_id  absolute_magnitude_h  \
# count  2.400000e+04      2.400000e+04          23992.000000
# mean   7.275111e+06      7.275111e+06             22.942274
# std    1.333987e+07      1.333987e+07              2.952871
# min    2.001981e+06      2.001981e+06             12.580000
# 25%    3.409962e+06      3.409962e+06             20.650000
# 50%    3.703790e+06      3.703790e+06             23.200000
# 75%    3.803897e+06      3.803897e+06             25.200000
# max    5.408749e+07      5.408749e+07             33.200000
#
#        kilometers_estimated_diameter_min  kilometers_estimated_diameter_max  \
# count                       23992.000000                       23992.000000
# mean                            0.167777                           0.375160
# std                             0.293000                           0.655169
# min                             0.000609                           0.001362
# 25%                             0.024241                           0.054205
# 50%                             0.060891                           0.136157
# 75%                             0.197040                           0.440595
# max                             8.101305                          18.115068
#
#        perihelion_distance  aphelion_distance
# count         24000.000000       24000.000000
# mean              0.915225           2.653104
# std               0.232201           4.468233
# min               0.070431           0.653754
# 25%               0.785150           1.706281
# 50%               0.965325           2.480109
# 75%               1.068984           3.397965
# max               1.299988         631.895456

# %% [markdown]
# *   min – минимальное значение признака
# *   max – максимальное значение признака
# *   mean – среднее значение
# *   std – среднеквадратическое отклонение
# *   25% – первый квартиль – значение, ниже которого лежит 25% значений
# *   50% – медиана – значение, 50% значений меньше которого, а другие 50% больше
# *   75% – третий квартиль – значение, ниже которого лежит около 75% значений

# %% [markdown]
# Матрица корреляции для числовых признаков

# %%
corrMatrix = df.select_dtypes(include=['float64']).corr()
corrMatrix.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_6c070_row0_col0, #T_6c070_row1_col1, #T_6c070_row1_col2, #T_6c070_row2_col1, #T_6c070_row2_col2, #T_6c070_row3_col3, #T_6c070_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6c070_row0_col1, #T_6c070_row0_col2, #T_6c070_row1_col0, #T_6c070_row2_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6c070_row0_col3, #T_6c070_row3_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_6c070_row0_col4, #T_6c070_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_6c070_row1_col3, #T_6c070_row2_col3, #T_6c070_row3_col1, #T_6c070_row3_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_6c070_row1_col4, #T_6c070_row2_col4, #T_6c070_row3_col4, #T_6c070_row4_col1, #T_6c070_row4_col2, #T_6c070_row4_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# </style>
# <table id="T_6c070" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c070_level0_col0" class="col_heading level0 col0" >absolute_magnitude_h</th>
#       <th id="T_6c070_level0_col1" class="col_heading level0 col1" >kilometers_estimated_diameter_min</th>
#       <th id="T_6c070_level0_col2" class="col_heading level0 col2" >kilometers_estimated_diameter_max</th>
#       <th id="T_6c070_level0_col3" class="col_heading level0 col3" >perihelion_distance</th>
#       <th id="T_6c070_level0_col4" class="col_heading level0 col4" >aphelion_distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c070_level0_row0" class="row_heading level0 row0" >absolute_magnitude_h</th>
#       <td id="T_6c070_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6c070_row0_col1" class="data row0 col1" >-0.715415</td>
#       <td id="T_6c070_row0_col2" class="data row0 col2" >-0.715415</td>
#       <td id="T_6c070_row0_col3" class="data row0 col3" >-0.036526</td>
#       <td id="T_6c070_row0_col4" class="data row0 col4" >-0.074962</td>
#     </tr>
#     <tr>
#       <th id="T_6c070_level0_row1" class="row_heading level0 row1" >kilometers_estimated_diameter_min</th>
#       <td id="T_6c070_row1_col0" class="data row1 col0" >-0.715415</td>
#       <td id="T_6c070_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6c070_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_6c070_row1_col3" class="data row1 col3" >-0.003524</td>
#       <td id="T_6c070_row1_col4" class="data row1 col4" >0.054581</td>
#     </tr>
#     <tr>
#       <th id="T_6c070_level0_row2" class="row_heading level0 row2" >kilometers_estimated_diameter_max</th>
#       <td id="T_6c070_row2_col0" class="data row2 col0" >-0.715415</td>
#       <td id="T_6c070_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_6c070_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6c070_row2_col3" class="data row2 col3" >-0.003524</td>
#       <td id="T_6c070_row2_col4" class="data row2 col4" >0.054581</td>
#     </tr>
#     <tr>
#       <th id="T_6c070_level0_row3" class="row_heading level0 row3" >perihelion_distance</th>
#       <td id="T_6c070_row3_col0" class="data row3 col0" >-0.036526</td>
#       <td id="T_6c070_row3_col1" class="data row3 col1" >-0.003524</td>
#       <td id="T_6c070_row3_col2" class="data row3 col2" >-0.003524</td>
#       <td id="T_6c070_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6c070_row3_col4" class="data row3 col4" >0.052073</td>
#     </tr>
#     <tr>
#       <th id="T_6c070_level0_row4" class="row_heading level0 row4" >aphelion_distance</th>
#       <td id="T_6c070_row4_col0" class="data row4 col0" >-0.074962</td>
#       <td id="T_6c070_row4_col1" class="data row4 col1" >0.054581</td>
#       <td id="T_6c070_row4_col2" class="data row4 col2" >0.054581</td>
#       <td id="T_6c070_row4_col3" class="data row4 col3" >0.052073</td>
#       <td id="T_6c070_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Наблюдается линейная корреляция у kilometers_estimated_diameter_min  и kilometers_estimated_diameter_max. Также оба эти признака сильно коррелируют с absolute_magnitude_h

# %% [markdown]
# # Обработка пропущенных значений

# %%
df.isnull().sum()
# Out:
# id                                       0
# neo_reference_id                         0
# name                                     0
# name_limited                         23856
# designation                              0
# absolute_magnitude_h                     8
# is_potentially_hazardous_asteroid        0
# is_sentry_object                         0
# kilometers_estimated_diameter_min        8
# kilometers_estimated_diameter_max        8
# orbit_id                                 0
# orbit_class_type                         0
# perihelion_distance                      0
# aphelion_distance                        0
# first_observation_date                   0
# last_observation_date                    0
# orbit_class_description                  0
# dtype: int64

# %% [markdown]
# Наблюдается примерно 99% пропущеных значений у name_limited

# %%
df['kilometers_estimated_diameter_max']=df['kilometers_estimated_diameter_max'].fillna(df['kilometers_estimated_diameter_max'].mean())
df['kilometers_estimated_diameter_min']=df['kilometers_estimated_diameter_min'].fillna(df['kilometers_estimated_diameter_min'].mean())
df['absolute_magnitude_h']=df['absolute_magnitude_h'].fillna(df['absolute_magnitude_h'].mean())

junk_features = ['id','neo_reference_id', 'name', 'name_limited','designation','orbit_id']
for i in junk_features:
    df=df.drop(i,axis='columns')

# %%
df.head()
# Out:
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                 15.22                               True             False
# 1                 15.97                              False             False
# 2                 16.36                              False             False
# 3                 17.10                              False             False
# 4                 17.28                              False             False
#
#    kilometers_estimated_diameter_min  kilometers_estimated_diameter_max  \
# 0                           2.401900                           5.370812
# 1                           1.700415                           3.802244
# 2                           1.420872                           3.177167
# 3                           1.010543                           2.259644
# 4                           0.930154                           2.079888
#
#   orbit_class_type  perihelion_distance  aphelion_distance  \
# 0              APO             0.621512           2.931360
# 1              AMO             1.238537           4.047945
# 2              AMO             1.050403           3.478155
# 3              ATE             0.790185           1.143633
# 4              APO             0.701397           1.454804
#
#   first_observation_date last_observation_date  \
# 0             1973-03-06            2021-10-20
# 1             1963-10-16            2021-04-15
# 2             1960-10-22            2021-06-12
# 3             1955-12-17            2019-11-10
# 4             1977-04-24            2021-12-02
#
#                              orbit_class_description
# 0  Near-Earth asteroid orbits which cross the Ear...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
# 3  Near-Earth asteroid orbits similar to that of ...
# 4  Near-Earth asteroid orbits which cross the Ear...

# %%
print(df.orbit_class_type.unique())
print(df.orbit_class_description.unique())
# Out:
# ['APO' 'AMO' 'ATE' 'IEO']
# ['Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo'
#  'Near-Earth asteroid orbits similar to that of 1221 Amor'
#  'Near-Earth asteroid orbits similar to that of 2062 Aten'
#  'An asteroid orbit contained entirely within the orbit of the Earth - Interior Earth Object']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
needed_encoding = ['orbit_class_type','orbit_class_description','is_potentially_hazardous_asteroid','is_sentry_object']
for i in needed_encoding:
    df[i]=label_encoder.fit_transform(df[i])
df.head()
# Out:
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                 15.22                                  1                 0
# 1                 15.97                                  0                 0
# 2                 16.36                                  0                 0
# 3                 17.10                                  0                 0
# 4                 17.28                                  0                 0
#
#    kilometers_estimated_diameter_min  kilometers_estimated_diameter_max  \
# 0                           2.401900                           5.370812
# 1                           1.700415                           3.802244
# 2                           1.420872                           3.177167
# 3                           1.010543                           2.259644
# 4                           0.930154                           2.079888
#
#    orbit_class_type  perihelion_distance  aphelion_distance  \
# 0                 1             0.621512           2.931360
# 1                 0             1.238537           4.047945
# 2                 0             1.050403           3.478155
# 3                 2             0.790185           1.143633
# 4                 1             0.701397           1.454804
#
#   first_observation_date last_observation_date  orbit_class_description
# 0             1973-03-06            2021-10-20                        3
# 1             1963-10-16            2021-04-15                        1
# 2             1960-10-22            2021-06-12                        1
# 3             1955-12-17            2019-11-10                        2
# 4             1977-04-24            2021-12-02                        3

# %% [markdown]
# # Обработка дат

# %%
date1=df['first_observation_date']
date2=df['last_observation_date']
date1=np.array(date1)
date2=np.array(date2)
for i in range(0,len(date1)):
    date1[i]=date1[i][:4]
    date2[i]=date2[i][:4]
date1=pd.DataFrame(date1)
date2=pd.DataFrame(date2)
df['first_observation_date']=date1
df['last_observation_date']=date2
df['first_observation_date']=label_encoder.fit_transform(df['first_observation_date'])
df['last_observation_date']=label_encoder.fit_transform(df['last_observation_date'])

# %% [markdown]
# Визуализация данных

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha = .01, figsize = (20, 20))
pass

# %%
df.corr()
# Out:
#                                    absolute_magnitude_h  \
# absolute_magnitude_h                           1.000000
# is_potentially_hazardous_asteroid             -0.298132
# is_sentry_object                               0.283209
# kilometers_estimated_diameter_min             -0.715316
# kilometers_estimated_diameter_max             -0.715316
# orbit_class_type                               0.209890
# perihelion_distance                           -0.036516
# aphelion_distance                             -0.074962
# first_observation_date                         0.520848
# last_observation_date                         -0.250442
# orbit_class_description                        0.196812
#
#                                    is_potentially_hazardous_asteroid  \
# absolute_magnitude_h                                       -0.298132
# is_potentially_hazardous_asteroid                           1.000000
# is_sentry_object                                           -0.058774
# kilometers_estimated_diameter_min                           0.174999
# kilometers_estimated_diameter_max                           0.174999
# orbit_class_type                                            0.167690
# perihelion_distance                                        -0.206415
# aphelion_distance                                           0.009947
# first_observation_date                                     -0.202053
# last_observation_date                                       0.100948
# orbit_class_description                                     0.201525
#
#                                    is_sentry_object  \
# absolute_magnitude_h                       0.283209
# is_potentially_hazardous_asteroid         -0.058774
# is_sentry_object                           1.000000
# kilometers_estimated_diameter_min         -0.109333
# kilometers_estimated_diameter_max         -0.109333
# orbit_class_type                           0.136328
# perihelion_distance                       -0.090673
# aphelion_distance                         -0.006609
# first_observation_date                     0.048992
# last_observation_date                     -0.105523
# orbit_class_description                    0.154503
#
#                                    kilometers_estimated_diameter_min  \
# absolute_magnitude_h                                       -0.715316
# is_potentially_hazardous_asteroid                           0.174999
# is_sentry_object                                           -0.109333
# kilometers_estimated_diameter_min                           1.000000
# kilometers_estimated_diameter_max                           1.000000
# orbit_class_type                                           -0.096205
# perihelion_distance                                        -0.003524
# aphelion_distance                                           0.054580
# first_observation_date                                     -0.589966
# last_observation_date                                       0.262973
# orbit_class_description                                    -0.080573
#
#                                    kilometers_estimated_diameter_max  \
# absolute_magnitude_h                                       -0.715316
# is_potentially_hazardous_asteroid                           0.174999
# is_sentry_object                                           -0.109333
# kilometers_estimated_diameter_min                           1.000000
# kilometers_estimated_diameter_max                           1.000000
# orbit_class_type                                           -0.096205
# perihelion_distance                                        -0.003524
# aphelion_distance                                           0.054580
# first_observation_date                                     -0.589966
# last_observation_date                                       0.262973
# orbit_class_description                                    -0.080573
#
#                                    orbit_class_type  perihelion_distance  \
# absolute_magnitude_h                       0.209890            -0.036516
# is_potentially_hazardous_asteroid          0.167690            -0.206415
# is_sentry_object                           0.136328            -0.090673
# kilometers_estimated_diameter_min         -0.096205            -0.003524
# kilometers_estimated_diameter_max         -0.096205            -0.003524
# orbit_class_type                           1.000000            -0.739767
# perihelion_distance                       -0.739767             1.000000
# aphelion_distance                         -0.090489             0.052073
# first_observation_date                     0.043575             0.000888
# last_observation_date                     -0.005666            -0.036527
# orbit_class_description                    0.736385            -0.612899
#
#                                    aphelion_distance  first_observation_date  \
# absolute_magnitude_h                       -0.074962                0.520848
# is_potentially_hazardous_asteroid           0.009947               -0.202053
# is_sentry_object                           -0.006609                0.048992
# kilometers_estimated_diameter_min           0.054580               -0.589966
# kilometers_estimated_diameter_max           0.054580               -0.589966
# orbit_class_type                           -0.090489                0.043575
# perihelion_distance                         0.052073                0.000888
# aphelion_distance                           1.000000               -0.007686
# first_observation_date                     -0.007686                1.000000
# last_observation_date                      -0.009332                0.209538
# orbit_class_description                    -0.033282                0.052052
#
#                                    last_observation_date  \
# absolute_magnitude_h                           -0.250442
# is_potentially_hazardous_asteroid               0.100948
# is_sentry_object                               -0.105523
# kilometers_estimated_diameter_min               0.262973
# kilometers_estimated_diameter_max               0.262973
# orbit_class_type                               -0.005666
# perihelion_distance                            -0.036527
# aphelion_distance                              -0.009332
# first_observation_date                          0.209538
# last_observation_date                           1.000000
# orbit_class_description                        -0.027406
#
#                                    orbit_class_description
# absolute_magnitude_h                              0.196812
# is_potentially_hazardous_asteroid                 0.201525
# is_sentry_object                                  0.154503
# kilometers_estimated_diameter_min                -0.080573
# kilometers_estimated_diameter_max                -0.080573
# orbit_class_type                                  0.736385
# perihelion_distance                              -0.612899
# aphelion_distance                                -0.033282
# first_observation_date                            0.052052
# last_observation_date                            -0.027406
# orbit_class_description                           1.000000

# %% [markdown]
# Визуализируем корреляцию всех признаков

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# count          24000.000000                       24000.000000
# mean              22.942274                           0.087250
# std                2.952379                           0.282207
# min               12.580000                           0.000000
# 25%               20.657500                           0.000000
# 50%               23.200000                           0.000000
# 75%               25.200000                           0.000000
# max               33.200000                           1.000000
#
#        is_sentry_object  kilometers_estimated_diameter_min  \
# count      24000.000000                       24000.000000
# mean           0.044417                           0.167777
# std            0.206023                           0.292951
# min            0.000000                           0.000609
# 25%            0.000000                           0.024241
# 50%            0.000000                           0.060891
# 75%            0.000000                           0.196361
# max            1.000000                           8.101305
#
#        kilometers_estimated_diameter_max  orbit_class_type  \
# count                       24000.000000      24000.000000
# mean                            0.375160          0.705625
# std                             0.655059          0.603518
# min                             0.001362          0.000000
# 25%                             0.054205          0.000000
# 50%                             0.136157          1.000000
# 75%                             0.439077          1.000000
# max                            18.115068          3.000000
#
#        perihelion_distance  aphelion_distance  first_observation_date  \
# count         24000.000000       24000.000000            24000.000000
# mean              0.915225           2.653104               57.866833
# std               0.232201           4.468233                7.938349
# min               0.070431           0.653754                0.000000
# 25%               0.785150           1.706281               54.000000
# 50%               0.965325           2.480109               60.000000
# 75%               1.068984           3.397965               64.000000
# max               1.299988         631.895456               66.000000
#
#        last_observation_date  orbit_class_description
# count           24000.000000             24000.000000
# mean               27.190375                 2.178333
# std                 4.837495                 0.946300
# min                 0.000000                 0.000000
# 25%                25.000000                 1.000000
# 50%                29.000000                 3.000000
# 75%                31.000000                 3.000000
# max                33.000000                 3.000000

# %% [markdown]
# *   min – минимальное значение признака
# *   max – максимальное значение признака
# *   mean – среднее значение
# *   std – среднеквадратическое отклонение
# *   25% – первый квартиль – значение, ниже которого лежит 25% значений
# *   50% – медиана – значение, 50% значений меньше которого, а другие 50% больше
# *   75% – третий квартиль – значение, ниже которого лежит около 75% значений

# %%
df.groupby('is_potentially_hazardous_asteroid').mean()
# Out:
#                                    absolute_magnitude_h  is_sentry_object  \
# is_potentially_hazardous_asteroid
# 0                                             23.214405          0.048160
# 1                                             20.095419          0.005253
#
#                                    kilometers_estimated_diameter_min  \
# is_potentially_hazardous_asteroid
# 0                                                           0.151927
# 1                                                           0.333589
#
#                                    kilometers_estimated_diameter_max  \
# is_potentially_hazardous_asteroid
# 0                                                           0.339719
# 1                                                           0.745928
#
#                                    orbit_class_type  perihelion_distance  \
# is_potentially_hazardous_asteroid
# 0                                          0.674336             0.930043
# 1                                          1.032951             0.760204
#
#                                    aphelion_distance  first_observation_date  \
# is_potentially_hazardous_asteroid
# 0                                           2.639363               58.362732
# 1                                           2.796859               52.679083
#
#                                    last_observation_date  \
# is_potentially_hazardous_asteroid
# 0                                              27.039396
# 1                                              28.769819
#
#                                    orbit_class_description
# is_potentially_hazardous_asteroid
# 0                                                 2.119374
# 1                                                 2.795129

# %% [markdown]
# #  Классификатор ближайших соседей и классификатор дерева решений. Случайный лес

# %%
X=np.array(df[['absolute_magnitude_h',
       'is_sentry_object', 'kilometers_estimated_diameter_min',
       'kilometers_estimated_diameter_max', 'orbit_class_type',
       'perihelion_distance', 'aphelion_distance', 'first_observation_date',
       'last_observation_date', 'orbit_class_description']])
y=np.array(df['is_potentially_hazardous_asteroid'])

# %% [markdown]
# Разбиение на обучающую и тестовую выборки

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
model1=KNeighborsClassifier(n_neighbors=3)      #Классификатор ближайших соседей
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()                 #Классификатор дерева решений

# %%
model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
print(model1," ",model1.score(X_test,y_test))
print(model2," ",model2.score(X_test,y_test))
# Out:
# KNeighborsClassifier(n_neighbors=3)   0.8976666666666666
# DecisionTreeClassifier()   0.9065

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 4, 5, 10, 15, 20, 25]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_                      #Лучшее значение ошибки
best_n_neighbors = grid.best_estimator_.n_neighbors     #Выбор оптимального значения гиперпараметра
print(best_cv_err, best_n_neighbors)
# Out:
# 0.0852222222222222 20

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.07811111111111112 0.08683333333333333

# %% [markdown]
#  Получили ошибки на обучающей и тестовой выборках

# %% [markdown]
# # Логистическая регрессия

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import  ConfusionMatrixDisplay
from sklearn import metrics

# %%
model = LogisticRegression(n_jobs = -1)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
pred_proba = model.predict_proba(X_test)[:,1]

# %% [markdown]
# Accuracy

# %%
accuracy_score(y_train, model.predict(X_train))
# Out:
# 0.9093333333333333

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.919

# %% [markdown]
# Вычисление ошибки на обучающей и тестовой выборке

# %%
err_train = np.mean(y_train != model.predict(X_train))
err_test  = np.mean(y_test  != model.predict(X_test))

print(err_train, err_test)
# Out:
# 0.09066666666666667 0.081

# %% [markdown]
# ROC-AUC

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, pred_proba)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
display.plot()

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# # Random forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier()

# %%
grid = GridSearchCV(rf, cv=5, param_grid = {'max_depth': [3, 6, 9],
    'min_samples_leaf': [3, 6, 9]},scoring='roc_auc',verbose = 2)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ....................max_depth=3, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=3, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=3, min_samples_leaf=3; total time=   0.8s
# [CV] END ....................max_depth=3, min_samples_leaf=3; total time=   1.3s
# [CV] END ....................max_depth=3, min_samples_leaf=3; total time=   0.9s
# [CV] END ....................max_depth=3, min_samples_leaf=6; total time=   0.8s
# [CV] END ....................max_depth=3, min_samples_leaf=6; total time=   0.8s
# [CV] END ....................max_depth=3, min_samples_leaf=6; total time=   0.9s
# [CV] END ....................max_depth=3, min_samples_leaf=6; total time=   0.8s
# [CV] END ....................max_depth=3, min_samples_leaf=6; total time=   0.9s
# [CV] END ....................max_depth=3, min_samples_leaf=9; total time=   0.9s
# [CV] END ....................max_depth=3, min_samples_leaf=9; total time=   0.8s
# [CV] END ....................max_depth=3, min_samples_leaf=9; total time=   0.9s
# [CV] END ....................max_depth=3, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=3, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=6, min_samples_leaf=3; total time=   1.5s
# [CV] END ....................max_depth=6, min_samples_leaf=3; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=3; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=3; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=3; total time=   1.0s
# [CV] END ....................max_depth=6, min_samples_leaf=6; total time=   1.0s
# [CV] END ....................max_depth=6, min_samples_leaf=6; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=6; total time=   1.0s
# [CV] END ....................max_depth=6, min_samples_leaf=6; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=6; total time=   1.0s
# [CV] END ....................max_depth=6, min_samples_leaf=9; total time=   1.3s
# [CV] END ....................max_depth=6, min_samples_leaf=9; total time=   1.5s
# [CV] END ....................max_depth=6, min_samples_leaf=9; total time=   1.5s
# [CV] END ....................max_depth=6, min_samples_leaf=9; total time=   1.1s
# [CV] END ....................max_depth=6, min_samples_leaf=9; total time=   1.0s
# [CV] END ....................max_depth=9, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=3; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=6; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=6; total time=   1.4s
# [CV] END ....................max_depth=9, min_samples_leaf=6; total time=   1.7s
# [CV] END ....................max_depth=9, min_samples_leaf=6; total time=   1.7s
# [CV] END ....................max_depth=9, min_samples_leaf=6; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=9; total time=   1.2s
# [CV] END ....................max_depth=9, min_samples_leaf=9; total time=   1.2s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 6, 9], 'min_samples_leaf': [3, 6, 9]},
#              scoring='roc_auc', verbose=2)

# %%
grid.best_params_
# Out:
# {'max_depth': 9, 'min_samples_leaf': 3}

# %%
rfst = ensemble.RandomForestClassifier(max_depth = grid.best_params_['max_depth'],min_samples_leaf = grid.best_params_['min_samples_leaf'])
rfst.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=9, min_samples_leaf=3)

# %% [markdown]
# Accuracy

# %%
accuracy_score(y_train, rfst.predict(X_train))
# Out:
# 0.9363888888888889

# %%
accuracy_score(y_test, rfst.predict(X_test))
# Out:
# 0.9196666666666666

# %% [markdown]
# Вычисление ошибки на обучающей и тестовой выборке

# %%
err_train = np.mean(y_train != rfst.predict(X_train))
err_test  = np.mean(y_test  != rfst.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0636111111111111 0.08033333333333334

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(y_test, rfst.predict(X_test))
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = rfst.classes_)
disp.plot()
plt.show()

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

# %%
model = MLPClassifier(hidden_layer_sizes=[100, 150])

# %%
model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=[100, 150])

# %%
accuracy_score(y_train, model.predict(X_train))
# Out:
# 0.9238888888888889

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.9185

# %% [markdown]
# Вычисление ошибки на обучающей и тестовой выборке

# %%
err_train = np.mean(y_train != model.predict(X_train))
err_test  = np.mean(y_test  != model.predict(X_test))

print(err_train, err_test)
# Out:
# 0.07611111111111112 0.0815

# %% [markdown]
# Ниже представлены графики зависимости ошибки на тесте от числа нейронов и параметра альфа

# %%
err_test = []

neurons = [5, 8, 10, 12, 15, 20, 25, 30, 40, 50, 60, 70]

for n in neurons:
    mlp_model = MLPClassifier(hidden_layer_sizes = (n,2),
                              activation = 'logistic', max_iter=1000, random_state = 42)
    mlp_model.fit(X_train, y_train)
    err_test.append(np.mean(y_test != mlp_model.predict(X_test)))

plt.semilogx(neurons, err_test, 'r-o', label = 'test')
plt.xlim([np.min(neurons), np.max(neurons)])
plt.title('Error от neurons')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()

# %%
err_test = []

alpha = [0.0001, 0.001, 0.01, 0.1, 0.5, 1, 5]

for al in alpha:
    mlp_model = MLPClassifier(hidden_layer_sizes = (10,2),
                              activation = 'logistic', alpha = al, max_iter=1000, random_state = 42)
    mlp_model.fit(X_train, y_train)
    err_test.append(np.mean(y_test != mlp_model.predict(X_test)))

plt.semilogx(alpha, err_test, 'r-o', label = 'test')
plt.xlim([np.min(alpha), np.max(alpha)])
plt.title('Error от alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()

# %% [markdown]
# # Итог

# %% [markdown]
# Мы обучили логистическую регрессию и случайный лес, для случайного леса мы подобрали оптимальные значения гиперпараметров. Построили confusion matrix. Переобучения не наблюдается.На тесте наименьшее значение ошибки получилось у случайного леса. Наибольшее значение accuracy на тесте получилось у случайного леса соответственно. Для MLP значение ошибки на тесте судя по графику не зависит от параметра альфа, но зависит от числа нейронов.
